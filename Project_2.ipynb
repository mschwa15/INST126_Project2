# %%
#This is the decryption function
def decrypt():
    plaintext = randWord
    ciphertext = ""
    i = 0
    while i < len(plaintext):
        if i % 2 == 0:
            plain_ascii = ord(plaintext[i])
            cipher_ascii = plain_ascii - 1
        else:
            plain_ascii = ord(plaintext[i])
            cipher_ascii = plain_ascii + 1        
        ciphertext += chr(cipher_ascii)
        i += 1
    print(f"The decrypted message is {ciphertext}")

#This is the beginning of the hangman game
    
import random
words = ["WHDSPQZ", "XHO", "TTDBFRT", "QQJYF", "ENQD", "DNPK", "CNTR", "EHWHOD", "TSVMOHOF", "XNOCFQGTM"]
randWord = random.choice(words)
attempts = []
lives = 10
while lives > 0:
    failed = 0
    for val in randWord:
        if val in attempts:
            print(val)
        else:
            print("-")
            failed += 1
    if failed == 0:
        print(f"Correct! The word was {randWord}")
        decrypt()
        break
    print('')
    guess = input("Guess a letter: ").upper()
    attempts.append(guess)
    if guess not in randWord:
        lives -= 1
        print(f"Incorrect")
    print(f"You have {lives} more lives left")
    if lives == 0:
        print(f"Game Over, the word was {randWord}")
        decrypt()
# Out:
# -
# -
# -
# -
# -
# -
# -
# -
#
# Guess a letter: m
# You have 10 more lives left
# -
# -
# -
# M
# -
# -
# -
# -
#
# Guess a letter: z
# Incorrect
# You have 9 more lives left
# -
# -
# -
# M
# -
# -
# -
# -
#
# Guess a letter: x
# Incorrect
# You have 8 more lives left
# -
# -
# -
# M
# -
# -
# -
# -
#
# Guess a letter: c
# Incorrect
# You have 7 more lives left
# -
# -
# -
# M
# -
# -
# -
# -
#
# Guess a letter: v
# You have 7 more lives left
# -
# -
# V
# M
# -
# -
# -
# -
#
# Guess a letter: b
# Incorrect
# You have 6 more lives left
# -
# -
# V
# M
# -
# -
# -
# -
#
# Guess a letter: n
# Incorrect
# You have 5 more lives left
# -
# -
# V
# M
# -
# -
# -
# -
#
# Guess a letter: a
# Incorrect
# You have 4 more lives left
# -
# -
# V
# M
# -
# -
# -
# -
#
# Guess a letter: s
# You have 4 more lives left
# -
# S
# V
# M
# -
# -
# -
# -
#
# Guess a letter: d
# Incorrect
# You have 3 more lives left
# -
# S
# V
# M
# -
# -
# -
# -
#
# Guess a letter: f
# You have 3 more lives left
# ...
